# %% [markdown]
# # Análisis de Redes Sociales
# ## Nombres
# ### Nucleo Guayas - Sociedad Ecuatoriana de Estadística
# #### Python Weekend 7/11/2020

# %%
# Importación de librerias
import tweepy
import csv
from tweepy import OAuthHandler
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#Credenciales y autenticaciones
consumer_key = 'XXXXXXXXXXXXXXXXXXXXXXXX'
consumer_secret = 'XXXXXXXXXXXXXXXXXXXXXXXX'
access_token = 'XXXXXXXXXXXXXXXXXXXXXXXX'
access_secret = 'XXXXXXXXXXXXXXXXXXXXXXXX'
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
#Revisar los tuits que se escribieron en los todos los contactos home
for status in tweepy.Cursor(api.XXX_timeline).items(XX):
    print(status.text)
# Out:
# RT @ArmenYuri: #Plagiarism, Fake Peer-Review, and Duplications
# @LatikaGupta_
# https://t.co/xN0TL5b1KG
# RT @elcomerciocom: ¡GRACIAS POR TANTO RICHIE! 👏😭❤️ Richard Carapaz termina en el podio como subcampeón de #LaVuelta a España 2020. La 'Loco…
# Al CM de Liga le debe estar picando los deditos con lo de Richard Carapaz.
# RT @RichardPAConway: Dr Yokose presents data from the CARDIA study. Fast food consumption had a strong association with serum urate. Extra…
# RT @ASotomayorEcu: ¡Richard Carapaz es Vicecampeón de La Vuelta a España 2020!
#
# El pedalista tricolor del Team @INEOSGrenadiers, no pudo ar…
# RT @INEOSGrenadiers: Always attacking, always exciting. It's a phenomenal effort from @RichardCarapazM as he gains 21 seconds on Roglic, bu…
# RT @savageeimear: Prof Bersmester's excellent overview on how our rheum treatments have evolved.  Hench memorial lecture. #ACR20
# Not all b…
# @RichardCarapazM le ganó SOLO hoy al EQUIPO Jumbo y a Roglic. SOLO.
#
# ...

# %%
#Revisar los tuits que realizo el user 
for status in tweepy.Cursor(api.###_timeline).items(10):
        print(status.text)
# Out:
# RT @Masappdata: ¿Ya estás inscrito? ¡MAÑANA! ➡️ Taller gratuito Introducción a Power BI y Análisis de KPIs. Conoce cómo analizar los datos…
# RT @gbaqueri: Comunicado de la ESPOL en conjunto con la EPN.
# RT @MashiRafael: Según Cedatos.😉 https://t.co/uEsM4jRnkN
# RT @NestorMontano: Desde @Masappdata hemos querido analizar lo que se dice sobre #Guayaquil en twitter con una muestra de tomada desde 22-j…
# RT @Masappdata: #Guayaquil celebró su #Bicentenario y nos preguntamos qué se dice de esta ciudad en Twitter. Usamos R y Shiny para analizar…
# RT @restevesd: #storytelling #DataVisualization
# RT @ElMercioEC: Biden gana Kentucky y estamos a la espera de los resultados en McDonalds, Carl’s Jr. y Burger King. Seguiremos informando.…
# Un tragajaso sobre Guayaquil https://t.co/2fQqpMhvRh
# Elegancia pura https://t.co/a8bMXRl58N
# Para tatuarlo en la memoria https://t.co/U3cbZ689Mc

# %%
#Revisar con hashtags
for status in tweepy.Cursor(api.search, q = "#######").items(##):
        print(status.text)
# Out:
# RT @JayJayTi: #guayaquil Necesito bartender, auxiliar de barra, cajero/a, meseros/as, cocineros/as y parrilleros/as para nuevo restaurante…
# RT @marcelaguinaga: La esperanza que vendrán mejores días junto al #BinomioArauzRabascall se hace sentir en cada rincón de la Patria.
# #LasM…
# RT @mcdc_mcdc: Uno de mis niños🎗 ha perdido TODA su dentadura por el cáncer.
# Imposible para su mamita costear algo así (consultas, radiogr…
# RT @mcdc_mcdc: Uno de mis niños🎗 ha perdido TODA su dentadura por el cáncer.
# Imposible para su mamita costear algo así (consultas, radiogr…
# Pero ya sabemos que ésto es solo un tontómetro las declaraciones  de ésta sra. @CynthiaViteri6, claro lo mas ancho… https://t.co/kTJMl9QLm9
# RT @paultutiven: #ATENCIÓN Anuncian nuevas medidas en #Guayaquil: prohibición de venta de bebidas alcohólicas, reducción de aforo en bares…
# ...

# %%
# http://docs.tweepy.org/en/v3.5.0/api.html
# https://towardsdatascience.com/how-to-scrape-more-information-from-tweets-on-twitter-44fd540b8a1f
# Que elementos se pueden capturar
with open ("Guayaquil.csv","w", newline ='\n', encoding = "utf-8") as csvwriter:
    writer = csv.writer(csvwriter,delimiter = "|")
    for status in tweepy.Cursor(api.search, q = "#Guayaquil").items(100):
        writer.writerow([status.created_at, status.user.screen_name,status.user.name,status.user.location,status.coordinates,status.place,status.retweet_count,status.favorite_count,status.text.replace("\n","")])

# %%
# http://docs.tweepy.org/en/v3.5.0/api.html
# https://towardsdatascience.com/how-to-scrape-more-information-from-tweets-on-twitter-44fd540b8a1f
# Que elementos se pueden capturar
with open ("Guayaquil.csv","w", newline ='\n', encoding = "utf-8") as csvwriter:
    writer = csv.writer(csvwriter,delimiter = "|")
    for status in tweepy.Cursor(api.search, q = "#Guayaquil").items(100):
        writer.writerow([status.created_at, status.user.screen_name,status.user.name,status.user.location,status.coordinates])

# %%
# http://docs.tweepy.org/en/v3.5.0/api.html
# https://towardsdatascience.com/how-to-scrape-more-information-from-tweets-on-twitter-44fd540b8a1f
# Que elementos se pueden capturar
with open ("Guayaquil.csv","w", newline ='\n', encoding = "utf-8") as csvwriter:
    writer = csv.writer(csvwriter,delimiter = "|")
    for status in tweepy.Cursor(api.search, q = "#Guayaquil").items(100):
        writer.writerow([status.created_at, status.user.screen_name,status.user.name,status.user.location,status.coordinates,status.place,status.retweet_count,status.favorite_count,status.text.replace("\n","")])

# %%
tweets_df = pd.read_csv('Guayaquil.csv',names=['Fecha','Screen_name','user_name','user_location','coordinates','place','retweet_count','favorite_count','text'],delimiter="|")

# %%
tweets_df.head()
# Out:
#                  Fecha      Screen_name                           user_name  \
# 0  2020-11-06 05:01:50  Vidasanaecuador  📱♥GYM EN LINEA Vida Sana Ecuador🖥️
# 1  2020-11-06 05:00:49           spncns                      Sandry Nogales
# 2  2020-11-06 04:59:05  patrici03034357                    patricia barrera
# 3  2020-11-06 04:58:26   AlbertoDentoFa                             Alberto
# 4  2020-11-06 04:56:57       Alex_F_Dom                      Alex_Dominguez
#
#          user_location  coordinates  place  retweet_count  favorite_count  \
# 0  Guayaquil - Ecuador          NaN    NaN              0               0
# 1     Machala, Ecuador          NaN    NaN             80               0
# 2                  NaN          NaN    NaN             33               0
# 3                  NaN          NaN    NaN             80               0
# 4          Gye-Ecuador          NaN    NaN             80               0
#
#                                                 text
# ...

# %%
tweets_df.dtypes
# Out:
# Fecha              object
# Screen_name        object
# user_name          object
# user_location      object
# coordinates       float64
# place              object
# retweet_count       int64
# favorite_count      int64
# text               object
# dtype: object

# %%
tweets_df["user_name"].value_counts().plot(kind='bar')

# %%
#Selecionar top de usuarios
tweets_df["user_name"].value_counts().nlargest(5).plot(kind='bar')

# %%
#Data frame con mas RT de tuits
tweets_df.groupby(["user_name"])["retweet_count"].sum().nlargest(10).reset_index()
# Out:
#                        user_name  retweet_count
# 0                         SPaezS            334
# 1                         Andres            277
# 2                 Martha Hidalgo            232
# 3                        Current            221
# 4       Aedryan Targaryen₅₂₀💜💚💜💚            179
# 5  Aquí se habla mal de correa .            179
# 6                   Carlos Soria            179
# 7            EDISON CORONEL MANC            179
# 8               Eduardo Guerrero            179
# 9                  Edwin Buendía            179

# %%
#Data frame con mas RT de tuits
tweets_df.groupby(["user_name"])["retweet_count"].sum().nlargest(10).plot(kind='bar')

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
#Extraigo un tuit 
text = tweets_df.text[0]

# %%
text
# Out:
# '#kapcakesbyck #Guayaquil #ecuador #reposteria #pasteleria #cupcakes #INSUMOSREPOSTERIA #tortasdecoradas… https://t.co/k89iPuAIYT'

# %%
#genero un word cloud de ese tuit
wordcloud = WordCloud().generate(text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
#Otro modelo de word cloud
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(text)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
wordcloud.to_file("Word.png")

# %%
#acumular el texto
text = " ".join(review for review in tweets_df.text)
print ("Hay {} palabras en la combinación de todos los tuits.".format(len(text)))
# Out:
# Hay 13397 palabras en la combinación de todos los tuits.

# %%
stopwords = set(STOPWORDS)
stopwords.update(["https", "mis", "por", "el", "de","mcdc_mcdc","RT"])

# %%
#https://www.datacamp.com/community/tutorials/wordcloud-python
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
def remove_url(txt):
    return " ".join(re.sub("([^0-9A-Za-z \t])|(\w+:\/\/\S+)", "", txt).split())

# %%
import re

# %%
text=remove_url(text)

# %%
text
# Out:
# 'GUAYAQUIL Mostly Sunny tomorrow With a high of 1660F and a low of 949F QUEDATENCASA ENTRENANDO CON NOSOTROS RT lahistoriaec Incidentes en el hospital del IESS Teodoro Maldonado Trabajadores de empresa de limpieza protestaron por la falta de pag RT AlertaMePerdi Perrito ENCONTRADO en el centro de GUAYAQUIL en la calles Brasil y Pio Montufar si alguien lo reconoce o lo est busc RT lahistoriaec Incidentes en el hospital del IESS Teodoro Maldonado Trabajadores de empresa de limpieza protestaron por la falta de pag RT lahistoriaec Incidentes en el hospital del IESS Teodoro Maldonado Trabajadores de empresa de limpieza protestaron por la falta de pag RT HolguerEC SOSEcuador Algunos videos que circulan de los destrozos ocasionados por los trabajadores de limpieza del hospital Teodor RT oromartv LoMsRelevanteDelDa Tras el aumento de casos COVID19 en Guayaquil los controles en la transportacin pblica se han in RT lahistoriaec Incidentes en el hospital del IESS Teodoro Maldonado Trabajadores 
# ...

# %%
#https://www.datacamp.com/community/tutorials/wordcloud-python
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
#https://www.earthdatascience.org/courses/use-data-open-source-python/intro-to-apis/analyze-tweet-sentiment-in-python/

# %%
from textblob import TextBlob

# %%
#defino funcion de limpieza
def clean_tweet(tweet): 
        return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

# %%
def get_tweet_sentiment(tweet):
        analysis = TextBlob(tweet)
        language = analysis.detect_language()
        if language == 'en':
            analysis_ready = analysis
        else:
            analysis_ready = analysis.translate(to='en')
            
        if analysis_ready.sentiment.polarity > 0: 
            return 'positive'
        elif analysis_ready.sentiment.polarity == 0: 
            return 'neutral'
        else: 
            return 'negative'

# %%
def get_tweet_sentiment_2(tweet):
        analysis = TextBlob(tweet)
        language = analysis.detect_language()

        analysis_ready = analysis    
        if analysis_ready.sentiment.polarity > 0: 
            return 'positive'
        elif analysis_ready.sentiment.polarity == 0: 
            return 'neutral'
        else: 
            return 'negative'

# %%
text = tweets_df.text[0]
blob_obj = TextBlob(text)
blob_obj.detect_language()
blob_obj.translate(to="bn")
# Out:
# TextBlob("# ক্যাপকেকসবাইক # গুয়ায়াকিল # সেকোডর # রিপোসটারিয়া # প্যাসিটেরিয়া # কুপকেকস #INSUMOSREPOSTERIA # টর্সাডেকোরডাস… https://t.co/k89iPuaiYT")

# %%
text = tweets_df.text[0]
blob_obj = TextBlob(text)
blob_obj.detect_language()
blob_obj.translate(to="en")
# Out:
# TextBlob("#kapcakesbyck #Guayaquil #ecuador #reposteria #pasteleria #cupcakes #INSUMOSREPOSTERIA # tortasdecoradas… https://t.co/k89iPuAIYT")

# %%
tweets_df["Sentimientos"] = tweets_df["text"].apply(get_tweet_sentiment)

# %%
tweets_df
# Out:
#                   Fecha      Screen_name                      user_name  \
# 0   2020-11-07 16:37:26         KAPCAKES                       KAPCAKES
# 1   2020-11-07 16:37:05       edwincitox                     edwincitox
# 2   2020-11-07 16:36:50        EcDelicia                 DeliciaMariaEc
# 3   2020-11-07 16:35:55   pamelitaeffect              Pamela Velz Muñoz
# 4   2020-11-07 16:34:08      bernardods1                      BernardoD
# 5   2020-11-07 16:33:56        alli4267R                     allisson67
# 6   2020-11-07 16:33:25   henrycordova29                 Henrycordova29
# 7   2020-11-07 16:30:18   RomperSilencio             SIN UN BUEN NOMBRE
# 8   2020-11-07 16:30:16    Tercerojo1963                     Tercer Ojo
# 9   2020-11-07 16:26:52        camposecu                      camposecu
# 10  2020-11-07 16:25:46  mariacarrillor8             mariacarrillorueda
# 11  2020-11-07 16:24:41         tvcomups                          TVcom
# ...

# %%
#Data frame con mas RT de tuits
tweets_df["Sentimientos"].value_counts().plot(kind='bar')

# %%
testimonial = TextBlob("guayaquil es hermosa")
testimonial.sentiment
# Out:
# Sentiment(polarity=0.0, subjectivity=0.0)

# %%
testimonial = TextBlob("guayaquil is beautiful")
testimonial.sentiment
# Out:
# Sentiment(polarity=0.85, subjectivity=1.0)

# %%
# https://thinkinfi.com/natural-language-processing-using-textblob/
# https://textblob.readthedocs.io/en/dev/api_reference.html#module-textblob.en.sentiments
# https://seraph13.medium.com/an%C3%A1lisis-de-sentimiento-de-tweets-con-python-y-tweepy-6754bf99a5bd

# %%
tweets_df_2=tweets_df[1:10]

# %%
tweets_df_2["Sentimientos2"] = tweets_df_2["text"].apply(get_tweet_sentiment)
# Out:
# C:\Users\acataguag\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
tweets_df_2
# Out:
#                  Fecha     Screen_name           user_name  \
# 1  2020-11-07 16:37:05      edwincitox          edwincitox
# 2  2020-11-07 16:36:50       EcDelicia      DeliciaMariaEc
# 3  2020-11-07 16:35:55  pamelitaeffect   Pamela Velz Muñoz
# 4  2020-11-07 16:34:08     bernardods1           BernardoD
# 5  2020-11-07 16:33:56       alli4267R          allisson67
# 6  2020-11-07 16:33:25  henrycordova29      Henrycordova29
# 7  2020-11-07 16:30:18  RomperSilencio  SIN UN BUEN NOMBRE
# 8  2020-11-07 16:30:16   Tercerojo1963          Tercer Ojo
# 9  2020-11-07 16:26:52       camposecu           camposecu
#
#                  user_location  coordinates place  retweet_count  \
# 1           Guayaquil, Ecuador          NaN   NaN            179
# 2  Gye - Sambo y Vía a la 🏖️☀️          NaN   NaN              0
# 3           Guayaquil, Ecuador          NaN   NaN              3
# 4                          NaN          NaN   NaN              1
# ...

# %%
#Data frame con mas RT de tuits
tweets_df_2["Sentimientos2"].value_counts().plot(kind='bar')

# %% [markdown]
# ## Taller
